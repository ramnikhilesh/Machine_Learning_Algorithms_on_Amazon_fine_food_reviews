# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')

haberman=pd.read_csv(r"C:\Users\Ram Nikhilesh\Desktop\ai class\csv files\haberman.csv",names=['Age','Op_Year','axil_nodes_det','Surv_status'])

# %%
haberman['Surv_status'].value_counts()
# Out:
# 1    225
# 2     81
# Name: Surv_status, dtype: int64

# %% [markdown]
# we can see this is a unbalanced data set having different values for the survive status.

# %%
haberman.head()
# Out:
#    Age  Op_Year  axil_nodes_det  Surv_status
# 0   30       64               1            1
# 1   30       62               3            1
# 2   30       65               0            1
# 3   31       59               2            1
# 4   31       65               4            1

# %% [markdown]
# sample data in haber man data set

# %%
sns.set_style("whitegrid")
sns.pairplot(haberman,hue='Surv_status',vars=['Age','Op_Year','axil_nodes_det'],size=7)
plt.show();

# %% [markdown]
# Observation:
#
# 1.with help of age and axil node detect we are able to distinguish the data (if axil node < 20 and age > 30 survived more than 5 years)
# 2.with help of op year and age we can also distinguish the data (if age > 30 and < 40 and undergone surgery survived more than 5 years)

# %%
sns.FacetGrid(haberman,hue='Surv_status',size=6)\
.map(sns.distplot,'axil_nodes_det')\
.add_legend();
plt.show();

# %% [markdown]
# observation:
#
# from the graph we have axil nodes det with hue surv status and we can observe that the pereson who are having axil nodes >0 and <=3 have survived more than 5 years and if axil nodes >3 most of the peple have died.

# %%
sns.FacetGrid(haberman,hue='Surv_status',size=6)\
.map(sns.distplot,'Age')\
.add_legend();
plt.show();

# %% [markdown]
# Observation:
#
# from the above graph we can see that if age > 30 and age < 40 they have survived more than 5 years and if age > 40 they have died within 5 years. here we cannot take any threshold value because it's a non uniform data set so there is more ambigious in the data.

# %%
sns.FacetGrid(haberman,hue='Surv_status',size=6)\
.map(sns.distplot,'Op_Year')\
.add_legend();
plt.show();

# %%
sns.boxplot(x='Surv_status',y='axil_nodes_det',data=haberman)
plt.show();

# %% [markdown]
# observation:
#
# in the above graph we can see the minimum and starting auxil node for survival 1 is 0 and for survival 2 is 1 and 75 percentile is 11

# %%
sns.boxplot(x='Surv_status',y='Age',data=haberman)
plt.show();

# %% [markdown]
# observation:
#
# the minimum age of surv 1 is 30 and 25th % is 44,50% is 54 and 75% is 60 the maximum is 77
# the minimum age of surv 2 is 34 and 25% is 45,50% is 54 and 75% is 61 the maximum is 85
# we can notice that it's  a nin uniform data so there is mostly mixed values.

# %%
sns.boxplot(x='Surv_status',y='Op_Year',data=haberman)
plt.show();

# %% [markdown]
# in the above graph we can notice that 78% of the people are survived.

# %%
counts, bin_edges = np.histogram(haberman['axil_nodes_det'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)



plt.show();
# Out:
# [0.77124183 0.09803922 0.05882353 0.02614379 0.02941176 0.00653595
#  0.00326797 0.         0.00326797 0.00326797]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %% [markdown]
# observation:
#
# we can observe that 78% of data have less than 10 auxil nodes

# %%
counts, bin_edges = np.histogram(haberman['Op_Year'], bins=10, 
                                 density = True)
pdf = counts/(sum(counts))
print(pdf);
print(bin_edges)

#compute CDF
cdf = np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf)
plt.plot(bin_edges[1:], cdf)



plt.show();
# Out:
# [0.20588235 0.09150327 0.08496732 0.0751634  0.09803922 0.10130719
#  0.09150327 0.09150327 0.08169935 0.07843137]
# [58.  59.1 60.2 61.3 62.4 63.5 64.6 65.7 66.8 67.9 69. ]

# %%
sns.violinplot(x="Surv_status", y="axil_nodes_det", data=haberman, size=8)
plt.show()

# %% [markdown]
# observation:
#
# we can observe the median and minimum value is o for survival 1 and for survival 2 we have 4 as median

# %%
sns.violinplot(x='Surv_status',y='Age',data=haberman,size=6)
plt.show();

# %% [markdown]
# observation:
#
# we have the median for surv statu 1 as 54 and median for surv status 2 as 56 with 25% and 75% as 44 and 60 for surv ststus 1 and for status 2 25% and 75% as 46 and 64

# %% [markdown]
# # Summary
# 1.from the above graphs we can observe that 78% of people have survived from cancer more than 5 years. who are having auxil node less than 10
# 2.if axil node < 20 and age > 30 survived more than 5 years
# 3.if age > 30 and < 40 and undergone surgery survived more than 5 years
